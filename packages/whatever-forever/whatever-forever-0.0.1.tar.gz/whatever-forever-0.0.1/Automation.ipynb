# %% [markdown]
# ## Automation
# Nothing too fancy here.

# %%
# !jupyter nbconvert --to python source/__init__.ipynb
# !jupyter nbconvert --to python source/chain.ipynb
# !jupyter nbconvert --to python source/magic.ipynb
# !cp source/__init__.py whatever4e/__init__.py
# !cp source/magic.py whatever4e/magic.py
# !cp source/chain.py whatever4e/chain.py
# !cp source/class_maker.py whatever4e/class_maker.py

# !jupyter nbconvert --to rst source/__init__.ipynb
# !cp source/__init__.rst README.rst

from glob import glob

for the_script in glob('whatever4e/*.py'):
    with open(the_script,'r') as f:
        src = f.read()
    with open(the_script,'w') as f:
        f.write(src.replace(
                'from class_maker import',
                'from .class_maker import'
            ))
        
# !python setup.py install
# Out:
# [NbConvertApp] Converting notebook source/__init__.ipynb to python
# [NbConvertApp] Writing 1625 bytes to source/__init__.py
# [NbConvertApp] Converting notebook source/chain.ipynb to python
# [NbConvertApp] Writing 4552 bytes to source/chain.py
# [NbConvertApp] Converting notebook source/magic.ipynb to python
# [NbConvertApp] Writing 2893 bytes to source/magic.py
# [NbConvertApp] Converting notebook source/__init__.ipynb to rst
# [NbConvertApp] Writing 1720 bytes to source/__init__.rst
# running install
# running bdist_egg
# running egg_info
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.5-x86_64/egg
# running install_lib
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# creating build/bdist.macosx-10.5-x86_64/egg
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/egg
# byte-compiling build/bdist.macosx-10.5-x86_64/egg/whatever4e.py to whatever4e.cpython-35.pyc
# creating build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/PKG-INFO -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/SOURCES.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/dependency_links.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/requires.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/top_level.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/whatever4e-0.2.0-py3.5.egg' and adding 'build/bdist.macosx-10.5-x86_64/egg' to it
# removing 'build/bdist.macosx-10.5-x86_64/egg' (and everything under it)
# Processing whatever4e-0.2.0-py3.5.egg
# Copying whatever4e-0.2.0-py3.5.egg to /Users/tfast/anaconda/lib/python3.5/site-packages
# Adding whatever4e 0.2.0 to easy-install.pth file
#
# Installed /Users/tfast/anaconda/lib/python3.5/site-packages/whatever4e-0.2.0-py3.5.egg
# Processing dependencies for whatever4e==0.2.0
# Searching for toolz==0.8.0
# Best match: toolz 0.8.0
# Adding toolz 0.8.0 to easy-install.pth file
#
# Using /Users/tfast/anaconda/lib/python3.5/site-packages
# Finished processing dependencies for whatever4e==0.2.0

# %%
# %%file setup.py
import os
from setuptools import setup


def read(fname):
    """
    Utility function to read the README file.
    Used for the long_description.  It's nice, because now 1) we have a top
    level README file and 2) it's easier to type in the README file than to put
    a raw string in below ...
    """
    with open(os.path.join(os.path.dirname(__file__), fname)) as f:
        return f.read()


setup(
    name="whatever-forever",
    version="0.0.1",
    author="Tony Fast",
    author_email="tony.fast@gmail.com",
    description="prototype whatever in the Jupyter notebook",
    license="BSD",
    keywords="IPython Magic Jupyter",
    url="http://github.com/tonyfast/whatever-forever",
    py_modules=["whatever-forever"],
    long_description=read("README.rst"),
    classifiers=[
        "Topic :: Utilities",
        "Framework :: IPython",
        "Natural Language :: English",
        "Programming Language :: Python",
        "Intended Audience :: Developers",
        "Development Status :: 3 - Alpha",
        "Operating System :: OS Independent",
        "Programming Language :: Python :: 3",
        "License :: OSI Approved :: BSD License",
        "Topic :: Software Development :: Testing",
    ],
    install_requires=[
        "toolz",
    ]
)
# Out:
# Overwriting setup.py

# %% [markdown]
# ### Run tests

# %%
# !python setup.py test

# %% [markdown]
# ### Check code style

# %%
# !flake8

# %% [markdown]
# ## Test Release for PyPi

# %%
# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest
# Out:
# running register
# running egg_info
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing whatever4e.egg-info/PKG-INFO
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# Registering whatever4e to https://testpypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing whatever4e.egg-info/PKG-INFO
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.3.0
# creating whatever4e-0.3.0/whatever4e.egg-info
# making hard links in whatever4e-0.3.0...
# hard linking Automation.ipynb -> whatever4e-0.3.0
# hard linking LICENSE -> whatever4e-0.3.0
# hard linking MANIFEST.in -> whatever4e-0.3.0
# hard linking Principal Component Viewer.ipynb -> whatever4e-0.3.0
# hard linking README.rst -> whatever4e-0.3.0
# hard linking Untitled.ipynb -> whatever4e-0.3.0
# hard linking Untitled1.ipynb -> whatever4e-0.3.0
# hard linking Untitled2.ipynb -> whatever4e-0.3.0
# hard linking setup.cfg -> whatever4e-0.3.0
# hard linking setup.py -> whatever4e-0.3.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.3.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.3.0
# Writing whatever4e-0.3.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.3.0' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0.dist-info/WHEEL
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.3.0
# creating whatever4e-0.3.0/whatever4e.egg-info
# making hard links in whatever4e-0.3.0...
# hard linking Automation.ipynb -> whatever4e-0.3.0
# hard linking LICENSE -> whatever4e-0.3.0
# hard linking MANIFEST.in -> whatever4e-0.3.0
# hard linking Principal Component Viewer.ipynb -> whatever4e-0.3.0
# hard linking README.rst -> whatever4e-0.3.0
# hard linking Untitled.ipynb -> whatever4e-0.3.0
# hard linking Untitled1.ipynb -> whatever4e-0.3.0
# hard linking Untitled2.ipynb -> whatever4e-0.3.0
# hard linking setup.cfg -> whatever4e-0.3.0
# hard linking setup.py -> whatever4e-0.3.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.3.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.3.0
# Writing whatever4e-0.3.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.3.0' (and everything under it)
# running upload
# Submitting dist/whatever4e-0.3.0.tar.gz to https://testpypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever4e-0.3.0-py2.py3-none-any.whl to https://testpypi.python.org/pypi
# Server response (200): OK

# %% [markdown]
# # Cut a real release for PyPi

# %%
# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi
# Out:
# running register
# running egg_info
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# Registering whatever4e to https://pypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.3.0
# creating whatever4e-0.3.0/whatever4e.egg-info
# making hard links in whatever4e-0.3.0...
# hard linking Automation.ipynb -> whatever4e-0.3.0
# hard linking LICENSE -> whatever4e-0.3.0
# hard linking MANIFEST.in -> whatever4e-0.3.0
# hard linking Principal Component Viewer.ipynb -> whatever4e-0.3.0
# hard linking README.rst -> whatever4e-0.3.0
# hard linking Untitled.ipynb -> whatever4e-0.3.0
# hard linking Untitled1.ipynb -> whatever4e-0.3.0
# hard linking Untitled2.ipynb -> whatever4e-0.3.0
# hard linking setup.cfg -> whatever4e-0.3.0
# hard linking setup.py -> whatever4e-0.3.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.3.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.3.0
# Writing whatever4e-0.3.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.3.0' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0.dist-info/WHEEL
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.3.0
# creating whatever4e-0.3.0/whatever4e.egg-info
# making hard links in whatever4e-0.3.0...
# hard linking Automation.ipynb -> whatever4e-0.3.0
# hard linking LICENSE -> whatever4e-0.3.0
# hard linking MANIFEST.in -> whatever4e-0.3.0
# hard linking Principal Component Viewer.ipynb -> whatever4e-0.3.0
# hard linking README.rst -> whatever4e-0.3.0
# hard linking Untitled.ipynb -> whatever4e-0.3.0
# hard linking Untitled1.ipynb -> whatever4e-0.3.0
# hard linking Untitled2.ipynb -> whatever4e-0.3.0
# hard linking setup.cfg -> whatever4e-0.3.0
# hard linking setup.py -> whatever4e-0.3.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.3.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.3.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.3.0
# Writing whatever4e-0.3.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.3.0' (and everything under it)
# running upload
# Submitting dist/whatever4e-0.3.0.tar.gz to https://pypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing whatever4e.egg-info/PKG-INFO
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.3.0.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever4e-0.3.0-py2.py3-none-any.whl to https://pypi.python.org/pypi
# Server response (200): OK
