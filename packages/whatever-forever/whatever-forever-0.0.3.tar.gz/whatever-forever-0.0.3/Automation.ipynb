# %% [markdown]
# ## Automation
# Nothing too fancy here.

# %%
# !jupyter nbconvert --to python source/__init__.ipynb
# !jupyter nbconvert --to python source/chain.ipynb
# !jupyter nbconvert --to python source/magic.ipynb
# !cp source/__init__.py whatever4e/__init__.py
# !cp source/magic.py whatever4e/magic.py
# !cp source/chain.py whatever4e/chain.py
# !cp source/class_maker.py whatever4e/class_maker.py

# !jupyter nbconvert --to rst source/__init__.ipynb
# !cp source/__init__.rst README.rst

from glob import glob

for the_script in glob('whatever4e/*.py'):
    with open(the_script,'r') as f:
        src = f.read()
    with open(the_script,'w') as f:
        f.write(src.replace(
                'from class_maker import',
                'from .class_maker import'
            ))
        
# !python setup.py install
# Out:
# [NbConvertApp] Converting notebook source/__init__.ipynb to python
# [NbConvertApp] Writing 1623 bytes to source/__init__.py
# [NbConvertApp] Converting notebook source/chain.ipynb to python
# [NbConvertApp] Writing 4542 bytes to source/chain.py
# [NbConvertApp] Converting notebook source/magic.ipynb to python
# [NbConvertApp] Writing 2120 bytes to source/magic.py
# [NbConvertApp] Converting notebook source/__init__.ipynb to rst
# [NbConvertApp] Writing 2211 bytes to source/__init__.rst
# running install
# running bdist_egg
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.5-x86_64/egg
# running install_lib
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# creating build/bdist.macosx-10.5-x86_64/egg
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/egg
# byte-compiling build/bdist.macosx-10.5-x86_64/egg/whatever4e.py to whatever4e.cpython-35.pyc
# creating build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever_forever.egg-info/PKG-INFO -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever_forever.egg-info/SOURCES.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever_forever.egg-info/dependency_links.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever_forever.egg-info/requires.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever_forever.egg-info/top_level.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/whatever_forever-0.0.2-py3.5.egg' and adding 'build/bdist.macosx-10.5-x86_64/egg' to it
# removing 'build/bdist.macosx-10.5-x86_64/egg' (and everything under it)
# Processing whatever_forever-0.0.2-py3.5.egg
# Removing /Users/tfast/anaconda/lib/python3.5/site-packages/whatever_forever-0.0.2-py3.5.egg
# Copying whatever_forever-0.0.2-py3.5.egg to /Users/tfast/anaconda/lib/python3.5/site-packages
# whatever-forever 0.0.2 is already the active version in easy-install.pth
#
# Installed /Users/tfast/anaconda/lib/python3.5/site-packages/whatever_forever-0.0.2-py3.5.egg
# Processing dependencies for whatever-forever==0.0.2
# Searching for toolz==0.8.0
# Best match: toolz 0.8.0
# Adding toolz 0.8.0 to easy-install.pth file
#
# Using /Users/tfast/anaconda/lib/python3.5/site-packages
# Finished processing dependencies for whatever-forever==0.0.2

# %%
# %%file setup.py
import os
from setuptools import setup


def read(fname):
    """
    Utility function to read the README file.
    Used for the long_description.  It's nice, because now 1) we have a top
    level README file and 2) it's easier to type in the README file than to put
    a raw string in below ...
    """
    with open(os.path.join(os.path.dirname(__file__), fname)) as f:
        return f.read()


setup(
    name="whatever-forever",
    version="0.0.2",
    author="Tony Fast",
    author_email="tony.fast@gmail.com",
    description="prototype whatever in the Jupyter notebook",
    license="BSD",
    keywords="IPython Magic Jupyter",
    url="http://github.com/tonyfast/whatever-forever",
    py_modules=["whatever-forever"],
    long_description=read("README.rst"),
    classifiers=[
        "Topic :: Utilities",
        "Framework :: IPython",
        "Natural Language :: English",
        "Programming Language :: Python",
        "Intended Audience :: Developers",
        "Development Status :: 3 - Alpha",
        "Operating System :: OS Independent",
        "Programming Language :: Python :: 3",
        "License :: OSI Approved :: BSD License",
        "Topic :: Software Development :: Testing",
    ],
    install_requires=[
        "toolz",
    ]
)
# Out:
# Overwriting setup.py

# %% [markdown]
# ### Run tests

# %%
# !python setup.py test

# %% [markdown]
# ### Check code style

# %%
# !flake8

# %% [markdown]
# ## Test Release for PyPi

# %%
# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest
# Out:
# running register
# running egg_info
# creating whatever_forever.egg-info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# Registering whatever-forever to https://testpypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.1
# creating whatever-forever-0.0.1/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.1...
# hard linking Automation.ipynb -> whatever-forever-0.0.1
# hard linking LICENSE -> whatever-forever-0.0.1
# hard linking MANIFEST.in -> whatever-forever-0.0.1
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.1
# hard linking README.rst -> whatever-forever-0.0.1
# hard linking Untitled.ipynb -> whatever-forever-0.0.1
# hard linking Untitled1.ipynb -> whatever-forever-0.0.1
# hard linking Untitled2.ipynb -> whatever-forever-0.0.1
# hard linking setup.cfg -> whatever-forever-0.0.1
# hard linking setup.py -> whatever-forever-0.0.1
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.1
# Writing whatever-forever-0.0.1/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.1' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.1-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.1.dist-info/WHEEL
# running sdist
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.1
# creating whatever-forever-0.0.1/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.1...
# hard linking Automation.ipynb -> whatever-forever-0.0.1
# hard linking LICENSE -> whatever-forever-0.0.1
# hard linking MANIFEST.in -> whatever-forever-0.0.1
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.1
# hard linking README.rst -> whatever-forever-0.0.1
# hard linking Untitled.ipynb -> whatever-forever-0.0.1
# hard linking Untitled1.ipynb -> whatever-forever-0.0.1
# hard linking Untitled2.ipynb -> whatever-forever-0.0.1
# hard linking setup.cfg -> whatever-forever-0.0.1
# hard linking setup.py -> whatever-forever-0.0.1
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.1/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.1
# Writing whatever-forever-0.0.1/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.1' (and everything under it)
# running upload
# Submitting dist/whatever-forever-0.0.1.tar.gz to https://testpypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.1-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.1.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever_forever-0.0.1-py2.py3-none-any.whl to https://testpypi.python.org/pypi
# Server response (200): OK

# %% [markdown]
# # Cut a real release for PyPi

# %%
# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi
# Out:
# running register
# running egg_info
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# Registering whatever-forever to https://pypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.2
# creating whatever-forever-0.0.2/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.2...
# hard linking Automation.ipynb -> whatever-forever-0.0.2
# hard linking LICENSE -> whatever-forever-0.0.2
# hard linking MANIFEST.in -> whatever-forever-0.0.2
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.2
# hard linking README.rst -> whatever-forever-0.0.2
# hard linking Untitled.ipynb -> whatever-forever-0.0.2
# hard linking Untitled1.ipynb -> whatever-forever-0.0.2
# hard linking Untitled2.ipynb -> whatever-forever-0.0.2
# hard linking setup.cfg -> whatever-forever-0.0.2
# hard linking setup.py -> whatever-forever-0.0.2
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.2
# Writing whatever-forever-0.0.2/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.2' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.2-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.2.dist-info/WHEEL
# running sdist
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.2
# creating whatever-forever-0.0.2/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.2...
# hard linking Automation.ipynb -> whatever-forever-0.0.2
# hard linking LICENSE -> whatever-forever-0.0.2
# hard linking MANIFEST.in -> whatever-forever-0.0.2
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.2
# hard linking README.rst -> whatever-forever-0.0.2
# hard linking Untitled.ipynb -> whatever-forever-0.0.2
# hard linking Untitled1.ipynb -> whatever-forever-0.0.2
# hard linking Untitled2.ipynb -> whatever-forever-0.0.2
# hard linking setup.cfg -> whatever-forever-0.0.2
# hard linking setup.py -> whatever-forever-0.0.2
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.2/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.2
# Writing whatever-forever-0.0.2/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.2' (and everything under it)
# running upload
# Submitting dist/whatever-forever-0.0.2.tar.gz to https://pypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.2-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever_forever-0.0.2.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever_forever-0.0.2-py2.py3-none-any.whl to https://pypi.python.org/pypi
# Server response (200): OK

# %%
# !pip install whatever-forever --upgrade
# Out:
# Requirement already up-to-date: whatever-forever in /Users/tfast/anaconda/lib/python3.5/site-packages
# Requirement already up-to-date: toolz in /Users/tfast/anaconda/lib/python3.5/site-packages (from whatever-forever)

# %%
# !pip uninstall whatever4e -y
# Out:
# Exception:
# Traceback (most recent call last):
#   File "/Users/tfast/anaconda/lib/python3.5/site-packages/pip/basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "/Users/tfast/anaconda/lib/python3.5/site-packages/pip/commands/uninstall.py", line 76, in run
#     requirement_set.uninstall(auto_confirm=options.yes)
#   File "/Users/tfast/anaconda/lib/python3.5/site-packages/pip/req/req_set.py", line 336, in uninstall
#     req.uninstall(auto_confirm=auto_confirm)
#   File "/Users/tfast/anaconda/lib/python3.5/site-packages/pip/req/req_install.py", line 687, in uninstall
#     '(at %s)' % (link_pointer, self.name, dist.location)
# AssertionError: Egg-link /Users/tfast/w4e does not match installed location of whatever4e (at /Users/tfast/anaconda/lib/python3.5/site-packages)
